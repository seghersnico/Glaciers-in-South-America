# %%
from functions import *
import seaborn as sns
sns.set_theme(style="darkgrid")

# %%
FILE_PATH = 'data/SA2_gla_MEAN-CAL-mass-change-series_obs_unobs.csv'
raw_data, long_data = load_glacier_data(FILE_PATH)

# %%
if raw_data is not None and long_data is not None:
    print("\nSuccessfully loaded and transformed glacier data.")
# Out:
# Successfully loaded and transformed glacier data.

# %%
raw_data
# Out:
#                RGIId REGION  O2Region   CenLon   CenLat   Area  WGMS_ID  \
# 0     RGI60-17.00001    SAN         2 -70.2602 -34.4356  0.888  35608.0
# 1     RGI60-17.00002    SAN         2 -70.2315 -34.4453  0.077  35609.0
# 2     RGI60-17.00003    SAN         2 -69.9941 -34.4720  0.028  35610.0
# 3     RGI60-17.00004    SAN         2 -70.3635 -34.4988  0.094  35611.0
# 4     RGI60-17.00005    SAN         2 -70.3407 -34.5327  0.058  35612.0
# ...              ...    ...       ...      ...      ...    ...      ...
# 6469  RGI60-17.15707    SAN         2 -68.5888 -26.4834  0.698  33584.0
# 6470  RGI60-17.15708    SAN         2 -68.5817 -26.4832  0.518  33585.0
# 6471  RGI60-17.15709    SAN         2 -68.5737 -26.4792  0.085  43100.0
# 6472  RGI60-17.15710    SAN         2 -68.3708 -26.4510  0.064  43101.0
# 6473  RGI60-17.15801    SAN         2 -72.2538 -44.5848  4.564  43142.0
#
#           1976      1977      1978  ...      2015      2016      2017  \
# 0    -1.470499 -1.676091 -0.874773  ... -1.858562 -2.422562 -0.490562
# 1    -1.261008 -1.466539 -0.665155  ... -1.650569 -2.214569 -0.282569
# 2    -0.529005 -0.734562  0.066793  ... -0.917904 -1.481904  0.450096
# 3    -0.990574 -1.196172 -0.394862  ... -1.378467 -1.942467 -0.010467
# 4    -1.318492 -1.524183 -0.722973  ... -1.704118 -2.268118 -0.336118
# ...        ...       ...       ...  ...       ...       ...       ...
# 6469 -0.430073 -0.635712  0.165554  ... -0.816967 -1.380967  0.551033
# 6470 -0.414135 -0.619734  0.181577  ... -0.802026 -1.366026  0.565974
# 6471 -0.334218 -0.539824  0.261478  ... -0.721918 -1.285918  0.646082
# 6472 -0.338738 -0.544367  0.256910  ... -0.725870 -1.289870  0.642130
# 6473 -0.459468 -0.665011  0.136360  ... -0.848723 -1.412723  0.519277
#
#           2018      2019      2020      2021      2022      2023      2024
# 0    -3.730562 -2.343814 -2.542441 -0.819546 -1.283654 -1.250315 -1.978175
# 1    -3.522569 -2.112885 -2.319746 -0.600850 -1.067270 -1.035429 -1.764336
# 2    -2.789904 -1.390339 -1.593568  0.127093 -0.338307 -0.305806 -1.034250
# 3    -3.250467 -1.866302 -2.064002 -0.340657 -0.804504 -0.770997 -1.498739
# 4    -3.576118 -2.226654 -2.411897 -0.682501 -1.142851 -1.107077 -1.833235
# ...        ...       ...       ...       ...       ...       ...       ...
# 6469 -2.688967 -1.320096 -1.512306  0.213706 -0.248600 -0.214093 -0.941137
# 6470 -2.674026 -1.289909 -1.487592  0.235762 -0.228080 -0.194570 -0.922309
# 6471 -2.593918 -1.212706 -1.409346  0.314514 -0.149036 -0.115335 -0.842942
# 6472 -2.597870 -1.225357 -1.418875  0.306503 -0.156170 -0.121902 -0.849112
# 6473 -2.720723 -1.315717 -1.520899  0.198813 -0.267135 -0.234989 -0.963682
#
# [6474 rows x 56 columns]

# %%
long_data
# Out:
#                  RGIId REGION  O2Region   CenLon   CenLat   Area  WGMS_ID  \
# 0       RGI60-17.00001    SAN         2 -70.2602 -34.4356  0.888  35608.0
# 1       RGI60-17.00002    SAN         2 -70.2315 -34.4453  0.077  35609.0
# 2       RGI60-17.00003    SAN         2 -69.9941 -34.4720  0.028  35610.0
# 3       RGI60-17.00004    SAN         2 -70.3635 -34.4988  0.094  35611.0
# 4       RGI60-17.00005    SAN         2 -70.3407 -34.5327  0.058  35612.0
# ...                ...    ...       ...      ...      ...    ...      ...
# 317221  RGI60-17.15707    SAN         2 -68.5888 -26.4834  0.698  33584.0
# 317222  RGI60-17.15708    SAN         2 -68.5817 -26.4832  0.518  33585.0
# 317223  RGI60-17.15709    SAN         2 -68.5737 -26.4792  0.085  43100.0
# 317224  RGI60-17.15710    SAN         2 -68.3708 -26.4510  0.064  43101.0
# 317225  RGI60-17.15801    SAN         2 -72.2538 -44.5848  4.564  43142.0
#
#         Year  Mass_Balance
# 0       1976     -1.470499
# 1       1976     -1.261008
# 2       1976     -0.529005
# 3       1976     -0.990574
# 4       1976     -1.318492
# ...      ...           ...
# 317221  2024     -0.941137
# 317222  2024     -0.922309
# 317223  2024     -0.842942
# 317224  2024     -0.849112
# 317225  2024     -0.963682
#
# [317226 rows x 9 columns]

# %%
# Plot average mass balance
plot_average_mass_balance(long_data)

# %%
plot_spectral_mass_balance(long_data, include_overlays=True, title_prefix="Average Glacier")
# Out:
# --- Starting Spectral Power Density (PSD) Analysis for Average Glacier ---
# --- Results for Average Glacier (PDO Range: 20-30 years) ---
#   Highest peak in PDO range: Period of 21.3 years
#   Frequency: 0.047 cycles/year
#   Power Spectral Density (PSD): 6.2736
#
# --- Results for Average Glacier (ENSO Range: 2-7 years) ---
#   Highest peak in ENSO range: Period of 2.7 years
#   Frequency: 0.375 cycles/year
#   Power Spectral Density (PSD): 7.5356

# %% [markdown]
# Interpretation of the combined PSD plot:
# - The blue line represents the Power Spectral Density (PSD) of the glacier mass balance data, calculated using Welch's method.
# - The Y-axis shows 'Power Spectral Density', which is a measure of energy per frequency unit.
# - Peaks in the PSD plot are generally 'smoother' and more reliable than those from a single FFT, thanks to segmentation and averaging.
# - The brown and purple lines are the scaled Kernel Density Estimates (KDEs) of your specified ENSO and PDO return periods.
# - Where the KDE peaks overlap with the PSD peaks, there is a strong correlation between the periodicity of your climate events and the energy distribution in the glacier mass balance.
#   Note: The scaling factors for the KDEs are adjusted based on the expected PSD values for better visual comparison.
#   You can experiment with the '* 0.9' scaling factor in the KDE scaling helper function to adjust the relative height for optimal visual comparison.

# %%
# Demonstrating the call for the average glacier, but without overlays
print("\n--- Plotting Average Glacier PSD WITHOUT Overlays ---")
plot_spectral_mass_balance(long_data, include_overlays=False, title_prefix="Average Glacier")
# Out:
# --- Plotting Average Glacier PSD WITHOUT Overlays ---
#
# --- Starting Spectral Power Density (PSD) Analysis for Average Glacier ---
# --- Results for Average Glacier (PDO Range: 20-30 years) ---
#   Highest peak in PDO range: Period of 21.3 years
#   Frequency: 0.047 cycles/year
#   Power Spectral Density (PSD): 6.2736
#
# --- Results for Average Glacier (ENSO Range: 2-7 years) ---
#   Highest peak in ENSO range: Period of 2.7 years
#   Frequency: 0.375 cycles/year
#   Power Spectral Density (PSD): 7.5356

# %%
# Plot glacier locations
plot_glacier_locations(long_data)
